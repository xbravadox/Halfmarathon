# %%
import boto3
import pandas as pd
from io import BytesIO
import os
from dotenv import load_dotenv
from pycaret.regression import *

load_dotenv()
# Out:
# True

# %%
load_dotenv()

# Konfiguracja połączenia
session = boto3.session.Session()
client = session.client('s3',
    region_name=os.getenv('DO_SPACES_REGION'),
    endpoint_url=os.getenv('DO_SPACES_ENDPOINT'),
    aws_access_key_id=os.getenv('DO_SPACES_KEY'),
    aws_secret_access_key=os.getenv('DO_SPACES_SECRET')
)

BUCKET_NAME = os.getenv('DO_SPACES_BUCKET')

# Wczytaj oczyszczone dane
obj = client.get_object(Bucket=BUCKET_NAME, Key='data/processed/halfmarathon_clean.csv')
df = pd.read_csv(BytesIO(obj['Body'].read()))

print(f"Wczytano {len(df)} rekordów")
print(df.head())
# Out:
# Wczytano 17730 rekordów
#   sex   age  time_5km_s  time_half_s
# 0   M  32.0       877.0       3899.0
# 1   M  38.0       888.0       3983.0
# 2   M  28.0       946.0       4104.0
# 3   M  36.0       971.0       4216.0
# 4   M  29.0       972.0       4227.0

# %%
from datetime import datetime

# Setup PyCaret
reg = setup(
    data=df,
    target='time_half_s',
    session_id=123,
    normalize=True,
    categorical_features=['sex'],
    numeric_features=['age', 'time_5km_s'],
    fold=5,
    verbose=False
)

# Porównaj modele
best_models = compare_models(n_select=3, sort='MAE')

# Wybierz najlepszy
best = best_models[0]

# Finalizuj model
final_model = finalize_model(best)

print(f"\nNajlepszy model: {best}")
# Out:
# <style type="text/css">
# #T_4edc0 th {
#   text-align: left;
# }
# #T_4edc0_row0_col0, #T_4edc0_row0_col2, #T_4edc0_row0_col3, #T_4edc0_row0_col4, #T_4edc0_row0_col5, #T_4edc0_row1_col0, #T_4edc0_row1_col1, #T_4edc0_row1_col2, #T_4edc0_row1_col3, #T_4edc0_row1_col4, #T_4edc0_row1_col5, #T_4edc0_row1_col6, #T_4edc0_row2_col0, #T_4edc0_row2_col1, #T_4edc0_row2_col6, #T_4edc0_row3_col0, #T_4edc0_row3_col1, #T_4edc0_row3_col2, #T_4edc0_row3_col3, #T_4edc0_row3_col4, #T_4edc0_row3_col5, #T_4edc0_row3_col6, #T_4edc0_row4_col0, #T_4edc0_row4_col1, #T_4edc0_row4_col2, #T_4edc0_row4_col3, #T_4edc0_row4_col4, #T_4edc0_row4_col5, #T_4edc0_row4_col6, #T_4edc0_row5_col0, #T_4edc0_row5_col1, #T_4edc0_row5_col2, #T_4edc0_row5_col3, #T_4edc0_row5_col4, #T_4edc0_row5_col5, #T_4edc0_row5_col6, #T_4edc0_row6_col0, #T_4edc0_row6_col1, #T_4edc0_row6_col2, #T_4edc0_row6_col3, #T_4edc0_row6_col4, #T_4edc0_row6_col5, #T_4edc0_row6_col6, #T_4edc0_row7_col0, #T_4edc0_row7_col1, #T_4edc0_row7_col2, #T_4edc0_row7_col3, #T_4edc0_row7_col4, #T_4edc0_row7_col5, #T_4edc0_row7_col6, #T_4edc0_row8_col0, #T_4edc0_row8_col1, #T_4edc0_row8_col2, #T_4edc0_row8_col3, #T_4edc0_row8_col4, #T_4edc0_row8_col5, #T_4edc0_row8_col6, #T_4edc0_row9_col0, #T_4edc0_row9_col1, #T_4edc0_row9_col2, #T_4edc0_row9_col3, #T_4edc0_row9_col4, #T_4edc0_row9_col5, #T_4edc0_row9_col6, #T_4edc0_row10_col0, #T_4edc0_row10_col1, #T_4edc0_row10_col2, #T_4edc0_row10_col3, #T_4edc0_row10_col4, #T_4edc0_row10_col5, #T_4edc0_row10_col6, #T_4edc0_row11_col0, #T_4edc0_row11_col1, #T_4edc0_row11_col2, #T_4edc0_row11_col3, #T_4edc0_row11_col4, #T_4edc0_row11_col5, #T_4edc0_row11_col6, #T_4edc0_row12_col0, #T_4edc0_row12_col1, #T_4edc0_row12_col2, #T_4edc0_row12_col3, #T_4edc0_row12_col4, #T_4edc0_row12_col5, #T_4edc0_row12_col6, #T_4edc0_row13_col0, #T_4edc0_row13_col1, #T_4edc0_row13_col2, #T_4edc0_row13_col3, #T_4edc0_row13_col4, #T_4edc0_row13_col5, #T_4edc0_row13_col6, #T_4edc0_row14_col0, #T_4edc0_row14_col1, #T_4edc0_row14_col2, #T_4edc0_row14_col3, #T_4edc0_row14_col4, #T_4edc0_row14_col5, #T_4edc0_row14_col6, #T_4edc0_row15_col0, #T_4edc0_row15_col1, #T_4edc0_row15_col2, #T_4edc0_row15_col3, #T_4edc0_row15_col4, #T_4edc0_row15_col5, #T_4edc0_row15_col6, #T_4edc0_row16_col0, #T_4edc0_row16_col1, #T_4edc0_row16_col2, #T_4edc0_row16_col3, #T_4edc0_row16_col4, #T_4edc0_row16_col5, #T_4edc0_row16_col6, #T_4edc0_row17_col0, #T_4edc0_row17_col1, #T_4edc0_row17_col2, #T_4edc0_row17_col3, #T_4edc0_row17_col4, #T_4edc0_row17_col5, #T_4edc0_row17_col6, #T_4edc0_row18_col0, #T_4edc0_row18_col1, #T_4edc0_row18_col2, #T_4edc0_row18_col3, #T_4edc0_row18_col4, #T_4edc0_row18_col5, #T_4edc0_row18_col6, #T_4edc0_row19_col0, #T_4edc0_row19_col1, #T_4edc0_row19_col2, #T_4edc0_row19_col3, #T_4edc0_row19_col4, #T_4edc0_row19_col5, #T_4edc0_row19_col6 {
#   text-align: left;
# }
# #T_4edc0_row0_col1, #T_4edc0_row0_col6, #T_4edc0_row2_col2, #T_4edc0_row2_col3, #T_4edc0_row2_col4, #T_4edc0_row2_col5 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_4edc0_row0_col7, #T_4edc0_row1_col7, #T_4edc0_row2_col7, #T_4edc0_row3_col7, #T_4edc0_row4_col7, #T_4edc0_row5_col7, #T_4edc0_row6_col7, #T_4edc0_row7_col7, #T_4edc0_row9_col7, #T_4edc0_row10_col7, #T_4edc0_row11_col7, #T_4edc0_row12_col7, #T_4edc0_row13_col7, #T_4edc0_row14_col7, #T_4edc0_row15_col7, #T_4edc0_row16_col7, #T_4edc0_row17_col7, #T_4edc0_row18_col7, #T_4edc0_row19_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_4edc0_row8_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_4edc0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4edc0_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_4edc0_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_4edc0_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_4edc0_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_4edc0_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_4edc0_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_4edc0_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_4edc0_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4edc0_level0_row0" class="row_heading level0 row0" >par</th>
#       <td id="T_4edc0_row0_col0" class="data row0 col0" >Passive Aggressive Regressor</td>
#       <td id="T_4edc0_row0_col1" class="data row0 col1" >291.1228</td>
#       <td id="T_4edc0_row0_col2" class="data row0 col2" >174513.9472</td>
#       <td id="T_4edc0_row0_col3" class="data row0 col3" >417.4171</td>
#       <td id="T_4edc0_row0_col4" class="data row0 col4" >0.8812</td>
#       <td id="T_4edc0_row0_col5" class="data row0 col5" >0.0579</td>
#       <td id="T_4edc0_row0_col6" class="data row0 col6" >0.0376</td>
#       <td id="T_4edc0_row0_col7" class="data row0 col7" >0.0180</td>
#     </tr>
#     <tr>
#       <th id="T_4edc0_level0_row1" class="row_heading level0 row1" >huber</th>
#       <td id="T_4edc0_row1_col0" class="data row1 col0" >Huber Regressor</td>
#       <td id="T_4edc0_row1_col1" class="data row1 col1" >291.2947</td>
#       <td id="T_4edc0_row1_col2" class="data row1 col2" >170852.8964</td>
#       <td id="T_4edc0_row1_col3" class="data row1 col3" >413.0130</td>
#       <td id="T_4edc0_row1_col4" class="data row1 col4" >0.8837</td>
#       <td id="T_4edc0_row1_col5" class="data row1 col5" >0.0570</td>
#       <td id="T_4edc0_row1_col6" class="data row1 col6" >0.0377</td>
#       <td id="T_4edc0_row1_col7" class="data row1 col7" >0.0200</td>
#     </tr>
#     <tr>
#       <th id="T_4edc0_level0_row2" class="row_heading level0 row2" >gbr</th>
#       <td id="T_4edc0_row2_col0" class="data row2 col0" >Gradient Boosting Regressor</td>
#       <td id="T_4edc0_row2_col1" class="data row2 col1" >295.1658</td>
#       <td id="T_4edc0_row2_col2" class="data row2 col2" >164210.0858</td>
#       <td id="T_4edc0_row2_col3" class="data row2 col3" >405.0585</td>
#       <td id="T_4edc0_row2_col4" class="data row2 col4" >0.8881</td>
#       <td id="T_4edc0_row2_col5" class="data row2 col5" >0.0513</td>
#       <td id="T_4edc0_row2_col6" class="data row2 col6" >0.0385</td>
#       <td id="T_4edc0_row2_col7" class="data row2 col7" >0.1100</td>
#     </tr>
#     <tr>
#       <th id="T_4edc0_level0_row3" class="row_heading level0 row3" >lasso</th>
#       <td id="T_4edc0_row3_col0" class="data row3 col0" >Lasso Regression</td>
#       <td id="T_4edc0_row3_col1" class="data row3 col1" >296.6818</td>
#       <td id="T_4edc0_row3_col2" class="data row3 col2" >167422.3432</td>
#       <td id="T_4edc0_row3_col3" class="data row3 col3" >408.8384</td>
#       <td id="T_4edc0_row3_col4" class="data row3 col4" >0.8860</td>
#       <td id="T_4edc0_row3_col5" class="data row3 col5" >0.0559</td>
#       <td id="T_4edc0_row3_col6" class="data row3 col6" >0.0388</td>
#       <td id="T_4edc0_row3_col7" class="data row3 col7" >0.2800</td>
#     </tr>
#     <tr>
#       <th id="T_4edc0_level0_row4" class="row_heading level0 row4" >llar</th>
#       <td id="T_4edc0_row4_col0" class="data row4 col0" >Lasso Least Angle Regression</td>
#       <td id="T_4edc0_row4_col1" class="data row4 col1" >296.6819</td>
#       <td id="T_4edc0_row4_col2" class="data row4 col2" >167422.2470</td>
#       <td id="T_4edc0_row4_col3" class="data row4 col3" >408.8383</td>
#       <td id="T_4edc0_row4_col4" class="data row4 col4" >0.8860</td>
#       <td id="T_4edc0_row4_col5" class="data row4 col5" >0.0559</td>
#       <td id="T_4edc0_row4_col6" class="data row4 col6" >0.0388</td>
#       <td id="T_4edc0_row4_col7" class="data row4 col7" >0.0160</td>
#     </tr>
#     <tr>
#       <th id="T_4edc0_level0_row5" class="row_heading level0 row5" >lr</th>
#       <td id="T_4edc0_row5_col0" class="data row5 col0" >Linear Regression</td>
#       <td id="T_4edc0_row5_col1" class="data row5 col1" >296.6972</td>
#       <td id="T_4edc0_row5_col2" class="data row5 col2" >167418.7697</td>
#       <td id="T_
# Najlepszy model: PassiveAggressiveRegressor(random_state=123)

# %%
import pickle
from io import BytesIO

# Zapisz model do pamięci
model_buffer = BytesIO()
pickle.dump(final_model, model_buffer)
model_buffer.seek(0)

# Nazwa pliku z datą
model_date = datetime.now().strftime('%Y%m%d')
model_filename = f'halfmarathon_model_v{model_date}.pkl'

# Upload do Spaces
client.put_object(
    Bucket=BUCKET_NAME,
    Key=f'models/{model_filename}',
    Body=model_buffer.getvalue(),
    ContentType='application/octet-stream'
)

# Upload jako latest.pkl
model_buffer.seek(0)
client.put_object(
    Bucket=BUCKET_NAME,
    Key='models/latest.pkl',
    Body=model_buffer.getvalue(),
    ContentType='application/octet-stream'
)

print(f"Model zapisany jako: models/{model_filename} i models/latest.pkl")
# Out:
# Model zapisany jako: models/halfmarathon_model_v20260103.pkl i models/latest.pkl

# %%
pickle.dump(final_model, open('../models/latest.pkl', 'wb'))
